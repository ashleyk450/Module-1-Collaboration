# %%
print("Testing assignment")
# Out:
# Testing assignment

# %% [markdown]
# The test results show whether the program is working correctly. When a test passes, it means the output matches what was expected. When a test fails, it means there is an error in the code that needs to be fixed. In my test, the result showed "OK," which means all tests passed successfully. This confirms that the function is working as intended for the test case provided. Testing helps catch mistakes early and makes code more reliable.
