# %%
# Name: Ashley King
# File Name: student_gpa_app.py
# Description: This program accepts student names and GPAs
# and determines if they qualify for the Dean's List or Honor Roll.

# %%
while True:
    last_name = input("Enter student's last name (or ZZZ to quit): ")
    
    if last_name == "ZZZ":
        break
# Out:
# Enter student's last name (or ZZZ to quit):  Smith
# Enter student's last name (or ZZZ to quit):  zzz
# Enter student's last name (or ZZZ to quit):  ZZZ

# %%
while True:
    last_name = input("Enter student's last name (or ZZZ to quit): ")
    
    if last_name == "ZZZ":
        break

    first_name = input("Enter student's first name: ")
    gpa = float(input("Enter student's GPA: "))

    if gpa >= 3.5:
        print(first_name, last_name, "made the Dean's List")
    elif gpa >= 3.25:
        print(first_name, last_name, "made the Honor Roll")
# Out:
# Enter student's last name (or ZZZ to quit):  Smith
# Enter student's first name:  John
# Enter student's GPA:  3.6
# John Smith made the Dean's List
# Enter student's last name (or ZZZ to quit):  Doe
# Enter student's first name:  Jane
# Enter student's GPA:  3.3
# Jane Doe made the Honor Roll
# Enter student's last name (or ZZZ to quit):  Brown
# Enter student's first name:  Mike
# Enter student's GPA:  2.9
# Enter student's last name (or ZZZ to quit):  Taylor
# Enter student's first name:  Chris
# Enter student's GPA:  3.5
# Chris Taylor made the Dean's List
# Enter student's last name (or ZZZ to quit):  White
# Enter student's first name:  Anna
# Enter student's GPA:  3.25
# Anna White made the Honor Roll
# Enter student's last name (or ZZZ to quit):  ZZZ
